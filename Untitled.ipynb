# %%
import sqlite3
conn=sqlite3.connect("users.db")
for row in conn.execute("SELECT id,device_name,device_key,farmer_id FROM devices"):
    print(row)
# Out:
# (1, 'Field-Device-1', 'dc5502a8566b439ab523c0a7be504c1cbc34388ef461428ba862f9aaad72f61a', 'farmer_001')
